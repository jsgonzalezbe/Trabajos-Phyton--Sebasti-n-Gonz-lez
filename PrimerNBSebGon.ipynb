# %% [markdown]
# Mi Primer Notebook *Google Colaboratory *

# %% [markdown]
# ## Primer Ejercicio Práctico Computación y Estadística

# %% [markdown]
# ruta_archivo = '/content/drive/MyDrive/11. Onceavo Semestre/Computación y estadística/clase1.xlsx'

# %% [markdown]
# #Cultivo de Pasifloras en Colombia

# %% [markdown]
# ## Punto 1

# %% [markdown]
# ## Punto

# %%
#1# Cargar tabla
# !pip install pandas 
import pandas as pd  
url = "/content/drive/MyDrive/11. Onceavo Semestre/Computación y estadística/Trabajo 1/Cultivospasifloras.xlsx"
Tabla = pd.read_excel(url)
Tabla.head(5)
# Out:
# ...
#       Departamento  Área (ha)  Producción (Ton)  Rendimiento (Ton/ha)
# 0            Huila       5482             54426                 14.83
# 1        Antioquia       3329             53135                 19.01
# 2             Meta       3724             35307                 15.89
# 3  Valle del cauca       1080             15238                 14.22

# %% [markdown]
# ## Punto 2

# %% [markdown]
#  * Cultivo Passiflorace
# ![Cultivo Passifloraceae](https://www.agromatica.es/wp-content/uploads/2013/12/Cultivo-de-Passiflora-1.jpg)
#
# [Link de la imagen](https://www.agromatica.es/wp-content/uploads/2013/12/Cultivo-de-Passiflora-1.jpg)

# %% [markdown]
# ## Punto 3

# %% [markdown]
# $$ \begin{vmatrix}
# 1 & 0 & 1 & 0 \\
# 10 & 20 & 30 & 40 \\
# 1 & 2 & 3 & 4 \\
# 5 & 4 & 3 & 2 \\
# \end{vmatrix} $$

# %% [markdown]
# ## Punto 4

# %% [markdown]
# $$ \begin{array}{|c|c|} \hline
# Fruta & Bebida & Postre & Lugar \\ \hline
# Pera & Soda & Galleta & Habitación \\
# Manzana & Tinto & Torta & Sotano \\
# Limon & Cafe & Oblea & Terraza \\ \hline
# \end{array} $$

# %% [markdown]
# ## Punto 5

# %% [markdown]
# * Volumen de una esfera
# $$ V=\frac{4}{3}\pi r{^3}= \int_{-r}^{r}\pi r{^2} dx -\int_{-r}^{r} \pi x{^2} dx $$
